# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("indeed_ds_jobs.csv")
df = df[df.Salary != "None"]
df
# Out:
#                                                  Title  \
# 0                                      Data Specialist
# 2                                       Data Scientist
# 6                                         Data Analyst
# 15                  SQL Analyst Programmer (Full-Time)
# 25             LECTURER IN DATA SCIENCE AND STATISTICS
# ..                                                 ...
# 685                           Manager | Risk Analytics
# 689                               Senior Web Developer
# 690                           Chief Technology Officer
# 717                        Fullstack Software Engineer
# 732  PhD Scholarship - Genetic and Physiological Ch...
#
#                                         Company                   Location  \
# 0                              Eutility Pty Ltd                       None
# 2    Department of Justice and Community Safety  Melbourne City Centre VIC
# 6                       Publicis Communications              Southbank VIC
# ...

# %%
salary = df['Salary'].apply(lambda x: x.split('a')[0])
remove_sign = salary.apply(lambda x: x.replace('$', ''))
salary_formatted = remove_sign.apply(lambda x: x.replace(',', '').replace(' ', ''))
df['Minimum Salary'] = salary_formatted.apply(lambda x: float((x.split('-'))[0]))
df['Maximum Salary'] = salary_formatted.apply(lambda x: float((x.split('-'))[-1]))
df['Average Salary'] = (df['Minimum Salary'] + df['Maximum Salary']) / 2
df
# Out:
#                                                  Title  \
# 0                                      Data Specialist
# 2                                       Data Scientist
# 6                                         Data Analyst
# 15                  SQL Analyst Programmer (Full-Time)
# 25             LECTURER IN DATA SCIENCE AND STATISTICS
# ..                                                 ...
# 685                           Manager | Risk Analytics
# 689                               Senior Web Developer
# 690                           Chief Technology Officer
# 717                        Fullstack Software Engineer
# 732  PhD Scholarship - Genetic and Physiological Ch...
#
#                                         Company                   Location  \
# 0                              Eutility Pty Ltd                       None
# 2    Department of Justice and Community Safety  Melbourne City Centre VIC
# 6                       Publicis Communications              Southbank VIC
# ...

# %%
def position(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data science' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'software engineer' in title.lower():
        return 'software engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'analytics' in title.lower():
        return 'analyst'
    elif 'data specialist' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning expert'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'research' in title.lower():
        return 'researcher'
    elif 'researcher' in title.lower():
        return 'researcher'
    else:
        return 'na'

# %%
df['Position'] = df['Title'].apply(position)
df['Position'].value_counts()
# Out:
# na                         74
# researcher                 28
# analyst                    24
# data scientist             13
# software engineer           8
# manager                     6
# data engineer               4
# machine learning expert     3
# Name: Position, dtype: int64
