# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("indeed_ds_jobs.csv")

# %%
df
# Out:
#                                           Title  \
# 0                                Data Scientist
# 1                            RESEARCH ASSISTANT
# 2       LECTURER IN DATA SCIENCE AND STATISTICS
# 3                            Research Assistant
# 4                            Research Assistant
# ..                                          ...
# 908  Research Scientist - Active Remote Sensing
# 909  Research Scientist - Active Remote Sensing
# 910  Research Scientist - Active Remote Sensing
# 911  Research Scientist - Active Remote Sensing
# 912  Research Scientist - Active Remote Sensing
#
#                                         Company                   Location  \
# 0    Department of Justice and Community Safety  Melbourne City Centre VIC
# 1                       University of Melbourne              Parkville VIC
# 2                       University of Melbourne              Parkville VIC
# 3          Murdoch Childrens Research Institute              Parkville VIC
# ...
